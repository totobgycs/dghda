# %%
import tensorflow as tf
import pandas as pd
import matplotlib as plt
import urllib.request, json

# %% [markdown]
# What data we use:
#   * biggest stocks from EUROSTOX50, NASDAQ and DOW (to limit input dimensionality)
#   * for the last 5 years (to have growing and volaile)
#   * daily oclh
# Where do we get them:

# %%
with urllib.request.urlopen("https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=AD.AMS&apikey=SLQLZPOJI7PGOISP") as url:
    data = json.loads(url.read().decode())
    print(data)
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes', '2. Symbol': 'AD.AMS', '3. Last Refreshed': '2019-02-01', '4. Output Size': 'Compact', '5. Time Zone': 'US/Eastern'}, 'Time Series (Daily)': {'2019-02-01': {'1. open': '23.0900', '2. high': '23.1500', '3. low': '22.8800', '4. close': '22.9450', '5. volume': '3522066'}, '2019-01-31': {'1. open': '23.0000', '2. high': '23.1000', '3. low': '22.6550', '4. close': '23.0200', '5. volume': '6522780'}, '2019-01-30': {'1. open': '23.4150', '2. high': '23.4200', '3. low': '23.2050', '4. close': '23.3300', '5. volume': '3114316'}, '2019-01-29': {'1. open': '23.4000', '2. high': '23.4900', '3. low': '23.3250', '4. close': '23.4000', '5. volume': '3138199'}, '2019-01-28': {'1. open': '23.2850', '2. high': '23.3700', '3. low': '23.0950', '4. close': '23.2150', '5. volume': '3750427'}, '2019-01-25': {'1. open': '23.1450', '2. high': '23.4750', '3. low': '23.0700', '4. close': '23.3850', '5. volume': '4711103'}, '2
# ...

# %%
data.keys()
# Out:
# dict_keys(['Meta Data', 'Time Series (Daily)'])

# %%
with urllib.request.urlopen("https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=AD.AMS&apikey=SLQLZPOJI7PGOISP") as url:
    data = json.loads(url.read().decode())
    df=pd.DataFrame.from_dict(data['Time Series (Daily)'], orient='index')

# %%
df.shape
# Out:
# (100, 5)

# %%
df
# Out:
#             1. open  2. high   3. low 4. close 5. volume
# 2018-09-12  20.8200  21.1050  20.8100  21.0350   4591378
# 2018-09-13  20.9700  21.1650  20.4000  20.4000   7745685
# 2018-09-14  20.2000  20.2000  18.6000  19.5000  13443413
# 2018-09-17  19.4320  20.0350  19.4100  19.7640   8649230
# 2018-09-18  19.7500  19.7600  19.3780  19.4660   6339305
# 2018-09-19  19.4440  19.6280  19.2160  19.2720   5692878
# 2018-09-20  19.1300  19.3140  18.8480  18.9320   8600313
# 2018-09-21  18.9000  19.3180  18.9000  19.3180  15648107
# 2018-09-24  19.2700  19.5180  19.2520  19.4500   6072056
# 2018-09-25  19.4200  19.6020  19.3420  19.4960   5041470
# 2018-09-26  19.4700  19.5960  19.4660  19.5600   3579751
# 2018-09-27  19.5120  19.7160  19.4260  19.7160   4194743
# 2018-09-28  19.7120  19.8640  19.6820  19.7500   6035966
# 2018-10-01  19.7200  19.7520  19.3700  19.3700   4418937
# 2018-10-02  19.3140  19.4040  19.1920  19.3700   4658888
# ...

# %%
type(df['1. open'])
# Out:
# pandas.core.series.Series
